# %% [markdown]
# # Data Collection
# - Zillow data - https://www.zillow.com/research/data/
# - Kaggle - https://www.kaggle.com/datasets/ahmedshahriarsakib/usa-real-estate-dataset?resource=download

# %%
# read the csv file into a dataframe
import csv
import sys
import pandas as pd
import numpy as np

# read the csv file into a dataframe
df = pd.read_csv("data/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  119729.572640
# 1    394913         1     New York, NY        msa        NY  214911.652349
# 2    753899         2  Los Angeles, CA        msa        CA  218489.647448
# 3    394463         3      Chicago, IL        msa        IL  150432.480390
# 4    394514         4       Dallas, TX        msa        TX  125268.936932
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  119940.215341  120201.443305  120761.726012  121406.544234  ...
# 1  215824.905614  216746.617250  218614.361683  220548.475724  ...
# 2  219302.706154  220385.692595  222540.471813  224897.124751  ...
# 3  150571.737044  150836.953795  151496.747161  152290.399220  ...
# 4  125324.732154  125388.874474  125555.445340  125775.064467  ...
#
#       2024-04-30     2024-05-31     2024-06-30     2024-07-31     2024-08-31  \
# ...

# %%
# show all columns
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  119729.572640
# 1    394913         1     New York, NY        msa        NY  214911.652349
# 2    753899         2  Los Angeles, CA        msa        CA  218489.647448
# 3    394463         3      Chicago, IL        msa        IL  150432.480390
# 4    394514         4       Dallas, TX        msa        TX  125268.936932
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31     2000-06-30  \
# 0  119940.215341  120201.443305  120761.726012  121406.544234  122097.876276
# 1  215824.905614  216746.617250  218614.361683  220548.475724  222692.726242
# 2  219302.706154  220385.692595  222540.471813  224897.124751  227237.273732
# 3  150571.737044  150836.953795  151496.747161  152290.399220  153181.091558
# 4  125324.732154  125388.874474  125555.445340  125775.064467  125997.364370
#
# ...

# %%
# list all columns
df.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        '2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30', '2000-05-31',
#        ...
#        '2024-04-30', '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#        '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31'],
#       dtype='object', length=306)
